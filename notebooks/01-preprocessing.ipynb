# %% [markdown]
# # Data Pre-Processing

# %%
import pandas as pd
from pathlib import Path
from sklearn.preprocessing import MinMaxScaler

# %%
data_path = Path("../data/raw.jsonl")
processed_data_path = Path("../data/processed.csv")
df = pd.read_json(data_path, lines=True)

# %%
df.head()
# Out:
#    movie_id               title release_date    budget  revenue_worldwide  \
# 0    983044   The Arctic Convoy   2023-12-25   6600000            3637940
# 1    851976         Small World   2021-09-10         0                  0
# 2        12        Finding Nemo   2003-05-30  94000000          940335536
# 3        16  Dancer in the Dark   2000-09-01  12500000           40061153
# 4        17            The Dark   2005-09-28         0            6593579
#
#    runtime                       genres     imdb_id  franchise  \
# 0      109                 [War, Drama]  tt27724113      False
# 1      117       [Crime, Action, Drama]  tt14319068      False
# 2      100          [Animation, Family]   tt0266543       True
# 3      140               [Drama, Crime]   tt0168629      False
# 4       87  [Horror, Thriller, Mystery]   tt0411267      False
#
#    cast_popularity_mean  cast_popularity_max  director_popularity  \
# 0              1.110400               2.1157               0.7560
# 1              1.366133               2.1604               0.6415
# 2              2.125667               2.9015               2.0785
# 3              2.485300               3.2558               3.4113
# 4              3.637300               6.2285               0.7014
#
#   original_language  imdb_rating  imdb_votes mpaa_rating  domestic_box_office  \
# 0                no          6.5      4266.0         N/A               2869.0
# 1                pl          5.6       927.0         N/A                  NaN
# 2                en          8.2   1185437.0           G          380843261.0
# 3                en          7.9    122419.0           R            4184036.0
# 4                en          5.3     11802.0           R                  NaN
#
#    rotten_tomatoes_score  metacritic_score  \
# 0                  100.0               NaN
# 1                    NaN               NaN
# 2                   99.0              90.0
# 3                   69.0              63.0
# 4                   40.0               NaN
#
#                                          awards_text
# 0                       3 wins & 6 nominations total
# 1                                              1 win
# 2        Won 1 Oscar. 49 wins & 63 nominations total
# 3  Nominated for 1 Oscar. 34 wins & 48 nomination...
# 4                                 1 nomination total

# %%
df.columns
# Out:
# Index(['movie_id', 'title', 'release_date', 'budget', 'revenue_worldwide',
#        'runtime', 'genres', 'imdb_id', 'franchise', 'cast_popularity_mean',
#        'cast_popularity_max', 'director_popularity', 'original_language',
#        'imdb_rating', 'imdb_votes', 'mpaa_rating', 'domestic_box_office',
#        'rotten_tomatoes_score', 'metacritic_score', 'awards_text'],
#       dtype='object')

# %% [markdown]
# ## Counting and Removing Duplicates

# %% [markdown]
# ## Converting Numerical Values From Strings

# %%
numerical_columns =[
    "budget",
    "revenue_worldwide",
    "runtime",
    "imdb_rating",
    "cast_popularity_mean",
    "cast_popularity_max",
    "director_popularity",
    "imdb_rating",
    "imdb_votes",
    "domestic_box_office",
    "rotten_tomatoes_score",
    "metacritic_score"
]

# %%
for col in numerical_columns:
    df[col] = pd.to_numeric(df[col], errors="coerce")

# %% [markdown]
# ## Dropping Empty Records

# %%
df.dropna(subset=[
    "budget",
    "revenue_worldwide",
    "imdb_rating",
    "budget",
    "imdb_rating",
    "cast_popularity_mean",
    "cast_popularity_max",
    "director_popularity"
], inplace=True)

# %% [markdown]
# ## Standardizing Values

# %%
scaler = MinMaxScaler()
df[numerical_columns] = scaler.fit_transform(df[numerical_columns])
df.head()
# Out:
#    movie_id               title release_date    budget  revenue_worldwide  \
# 0    983044   The Arctic Convoy   2023-12-25  0.013472           0.001759
# 1    851976         Small World   2021-09-10  0.000000           0.000000
# 2        12        Finding Nemo   2003-05-30  0.191876           0.454659
# 3        16  Dancer in the Dark   2000-09-01  0.025515           0.019370
# 4        17            The Dark   2005-09-28  0.000000           0.003188
#
#     runtime                       genres     imdb_id  franchise  \
# 0  0.186325                 [War, Drama]  tt27724113      False
# 1  0.200000       [Crime, Action, Drama]  tt14319068      False
# 2  0.170940          [Animation, Family]   tt0266543       True
# 3  0.239316               [Drama, Crime]   tt0168629      False
# 4  0.148718  [Horror, Thriller, Mystery]   tt0411267      False
#
#    cast_popularity_mean  cast_popularity_max  director_popularity  \
# 0              0.057893             0.054080             0.045147
# 1              0.071943             0.055254             0.038178
# 2              0.113672             0.074722             0.125648
# 3              0.133430             0.084029             0.206776
# 4              0.196721             0.162118             0.041824
#
#   original_language  imdb_rating  imdb_votes mpaa_rating  domestic_box_office  \
# 0                no     0.666667    0.001341         N/A             0.000003
# 1                pl     0.551282    0.000265         N/A                  NaN
# 2                en     0.884615    0.381986           G             0.406596
# 3                en     0.846154    0.039417           R             0.004466
# 4                en     0.512821    0.003769           R                  NaN
#
#    rotten_tomatoes_score  metacritic_score  \
# 0                   1.00               NaN
# 1                    NaN               NaN
# 2                   0.99          0.913043
# 3                   0.69          0.619565
# 4                   0.40               NaN
#
#                                          awards_text
# 0                       3 wins & 6 nominations total
# 1                                              1 win
# 2        Won 1 Oscar. 49 wins & 63 nominations total
# 3  Nominated for 1 Oscar. 34 wins & 48 nomination...
# 4                                 1 nomination total

# %% [markdown]
# ## Extracting Months

# %%
df['release_date'] = pd.to_datetime(df['release_date'])

# %%
df['month'] = df['release_date'].dt.month

# %%
def assign_season(month):
    if month in [6, 7, 8]: return 'Summer'
    if month in [12, 1, 2]: return 'Winter'
    return 'Other'

# %%
df['season'] = df['month'].apply(assign_season)

# %% [markdown]
# ## Renaming Critics Score and Audience Rating

# %%
df['critics_score'] = df[['rotten_tomatoes_score', 'metacritic_score']].mean(axis=1)
df['audience_score'] = df['imdb_rating']

# %% [markdown]
# ## Saving the Processed Data

# %%
df.to_csv(processed_data_path)

# %% [markdown]
# ---
