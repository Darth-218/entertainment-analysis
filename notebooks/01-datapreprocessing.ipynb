# %% [markdown]
# # Import Libraries and Data

# %%
import os
import pandas as pd
import json

# %%
os.getcwd()
# Out:
# 'c:\\Users\\nardi\\OneDrive\\Desktop\\DataAnalysis\\entertainment-analysis\\notebooks'

# %%
df = pd.read_json(r"C:\Users\nardi\OneDrive\Desktop\DataAnalysis\entertainment-analysis\data\raw.jsonl", lines=True)

# %%
df.head()
# Out:
#    movie_id                                title release_date    budget  \
# 0      8193                    Napoleon Dynamite   2004-06-11    400000
# 1    663558               New Gods: Nezha Reborn   2021-02-06         0
# 2    614409  To All the Boys: Always and Forever   2021-02-12         0
# 3        12                         Finding Nemo   2003-05-30  94000000
# 4        16                   Dancer in the Dark   2000-09-01  12500000
#
#    revenue_worldwide  runtime                        genres     imdb_id  \
# 0           46118097       95                      [Comedy]   tt0374900
# 1           70000000      117  [Animation, Fantasy, Action]  tt13269670
# 2                  0      115      [Romance, Comedy, Drama]  tt10676012
# 3          940335536      100           [Animation, Family]   tt0266543
# 4           40061153      140                [Drama, Crime]   tt0168629
#
#    franchise  cast_popularity_mean  cast_popularity_max  director_popularity  \
# ...

# %%
df
# Out:
#       movie_id                                title release_date     budget  \
# 0         8193                    Napoleon Dynamite   2004-06-11     400000
# 1       663558               New Gods: Nezha Reborn   2021-02-06          0
# 2       614409  To All the Boys: Always and Forever   2021-02-12          0
# 3           12                         Finding Nemo   2003-05-30   94000000
# 4           16                   Dancer in the Dark   2000-09-01   12500000
# ...        ...                                  ...          ...        ...
# 2595    147441               Exodus: Gods and Kings   2014-12-03  140000000
# 2596    499701       Dora and the Lost City of Gold   2019-08-08   49000000
# 2597    917496              Beetlejuice Beetlejuice   2024-09-04   99000000
# 2598     73723                            The Lorax   2012-03-01   70000000
# 2599    638974                     Murder Mystery 2   2023-03-28          0
#
# ...

# %%
df
# Out:
#      movie_id                                title release_date    budget  \
# 0        8193                    Napoleon Dynamite   2004-06-11    400000
# 1      663558               New Gods: Nezha Reborn   2021-02-06         0
# 2      614409  To All the Boys: Always and Forever   2021-02-12         0
# 3          12                         Finding Nemo   2003-05-30  94000000
# 4          16                   Dancer in the Dark   2000-09-01  12500000
# ..        ...                                  ...          ...       ...
# 796    157544                    The Vatican Tapes   2015-07-23  13000000
# 797      1900                              Traffic   2000-12-27  48000000
# 798     51052                     Arthur Christmas   2011-11-10  10000000
# 799      1903                          Vanilla Sky   2001-12-14  68000000
# 800      1904                  Memoirs of a Geisha   2005-12-06  85000000
#
#      revenue_worldwide  runtime                               genres  \
# ...

# %%
df.columns
# Out:
# Index(['movie_id', 'title', 'release_date', 'budget', 'revenue_worldwide',
#        'runtime', 'genres', 'imdb_id', 'franchise', 'cast_popularity_mean',
#        'cast_popularity_max', 'director_popularity', 'original_language',
#        'imdb_rating', 'imdb_votes', 'mpaa_rating', 'domestic_box_office',
#        'rotten_tomatoes_score', 'metacritic_score', 'awards_text', 'profit',
#        'roi'],
#       dtype='object')

# %%
q1_df = df[[
    "budget",
    "revenue_worldwide",
    "roi",
    "imdb_rating",
    "cast_popularity_mean",
    "cast_popularity_max",
    "director_popularity"
]].copy()

# %%
for col in q1_df.columns:
    q1_df[col] = pd.to_numeric(q1_df[col], errors="coerce")

# %%
q1_df = q1_df.dropna(subset=[
    "budget",
    "revenue_worldwide",
    "imdb_rating"
])

# %%
q1_df["imdb_rating"] = q1_df["imdb_rating"] / 10
q1_df["cast_popularity_mean"] = (
    q1_df["cast_popularity_mean"] - q1_df["cast_popularity_mean"].mean()
) / q1_df["cast_popularity_mean"].std()

q1_df["budget"] = (
    q1_df["budget"] - q1_df["budget"].mean()
) / q1_df["budget"].std()

# %%
q1_df["box_office_success"] = q1_df["roi"]

# %%
q1_final = q1_df[[
    "box_office_success",
    "budget",
    "imdb_rating",
    "cast_popularity_mean",
    "cast_popularity_max",
    "director_popularity"
]].dropna()

# %%
q1_final.corr()["box_office_success"].sort_values(ascending=False)
# Out:
# box_office_success      1.000000
# imdb_rating             0.037601
# director_popularity     0.007575
# cast_popularity_max    -0.080653
# cast_popularity_mean   -0.095876
# budget                 -0.124160
# Name: box_office_success, dtype: float64

# %%
df['release_date'] = pd.to_datetime(df['release_date'])
# Out:
# C:\Users\nardi\AppData\Local\Temp\ipykernel_13708\1525507706.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['release_date'] = pd.to_datetime(df['release_date'])

# %%
df['month'] = df['release_date'].dt.month
# Out:
# C:\Users\nardi\AppData\Local\Temp\ipykernel_13708\4046624750.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['month'] = df['release_date'].dt.month

# %%
def assign_season(month):
    if month in [6, 7, 8]: return 'Summer'
    if month in [12, 1, 2]: return 'Winter'
    return 'Other'

df['season'] = df['month'].apply(assign_season)
# Out:
# C:\Users\nardi\AppData\Local\Temp\ipykernel_13708\1234277538.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['season'] = df['month'].apply(assign_season)

# %%
q2_df = df[(df['season'].isin(['Summer', 'Winter'])) & (df['revenue_worldwide'] > 0)].copy()

# %%
seasonal_comparison = q2_df.groupby('season')['revenue_worldwide'].mean().sort_values(ascending=False)

print("Average Worldwide Revenue by Season:")
print(seasonal_comparison)
# Out:
# Average Worldwide Revenue by Season:
# season
# Summer    2.341969e+08
# Winter    2.190730e+08
# Name: revenue_worldwide, dtype: float64
